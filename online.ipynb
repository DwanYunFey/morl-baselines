# %%
from mo_gymnasium import envs

# 打印所有环境模块
print("MO-Gymnasium 环境模块：")
for env_module in dir(envs):
    if not env_module.startswith("_"):
        print(f"- {env_module}")
# Out:
# MO-Gymnasium 环境模块：
# - breakable_bottles
# - continuous_mountain_car
# - deep_sea_treasure
# - fishwood
# - four_room
# - fruit_tree
# - highway
# - lunar_lander
# - mario
# - minecart
# - mo_gymnasium
# - mountain_car
# - mujoco
# - resource_gathering
# - water_reservoir
